# %% [markdown]
# # Welcome to Colab Python Starter Notebook
#
# This is a sample notebook in your new repository. Feel free to edit and add your own code!

# %%
print('Hello, world! 👋')
# Out:
# Hello, world! 👋
